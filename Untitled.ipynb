# %%
from deepface import DeepFace
from PIL import Image
import numpy as np

# %%
face_objs = DeepFace.extract_faces(
    img_path="img1.jpg",
    detector_backend="opencv",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 face_objs = DeepFace.extract_faces(
#       2     img_path="img1.jpg",
#       3     detector_backend="opencv",
#       4 )
#
# File ~/ait/eqx-mobilefacenet/.venv/lib/python3.11/site-packages/deepface/DeepFace.py:549, in extract_faces(img_path, detector_backend, enforce_detection, align, expand_percentage, grayscale, color_face, normalize_face, anti_spoofing)
#     489 def extract_faces(
#     490     img_path: Union[str, np.ndarray],
#     491     detector_backend: str = "opencv",
#    (...)    498     anti_spoofing: bool = False,
#     499 ) -> List[Dict[str, Any]]:
#     500     """
#     501     Extract faces from a given image
#     502
#    (...)    546             just available in the result only if anti_spoofing is set to True in input arguments.
#     547     """
# ...

# %%
Image.fromarray(np.uint8(face_objs[0]['face'] * 255))
# Out:
# <PIL.Image.Image image mode=RGB size=319x435>
